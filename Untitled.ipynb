# %%
import turtle
turtle.bgcolor("cadetblue1")

t = turtle.Turtle()
t.speed(20)
m = 250
n = 210
a = 90


t.pensize(2)

t.penup()
t.goto(-500,-300)
t.pendown()

# vẽ ngôi nhà mơ ước
#vẽ hình chữ nhật mặt trước
t.fillcolor("#8581BD")
t.begin_fill()
t.forward(n)
t.left(90)
t.forward(m)
t.left(90)
t.forward(n)
t.left(90)
t.forward(m)
t.end_fill()
# ve cua truoc
t.fillcolor("aquamarine3")
t.begin_fill()
t.penup()
t.goto(-440,-300)
t.pendown()
t.left(90)
t.forward(90)
t.left(90)
t.forward(130)
t.left(90)
t.forward(90)
t.left(90)
t.forward(130)
t.end_fill()
#vẽ mặt bên ngôi nhà
t.fillcolor("#1D5B88")
t.begin_fill()
t.penup()
t.goto(-290,-300)
t.pendown()
t.left(120)
t.forward(150)
t.left(60)
t.forward(m)
t.left(120)
t.forward(150)
t.left(60)
t.forward(m)
t.end_fill()
#vẽ cửa sổ bên
t.fillcolor("#AC5B66")
t.begin_fill()
t.penup()
t.goto(-240,-100)
t.pendown()
t.forward(70)
t.left(120)
t.forward(50)
t.left(60)
t.forward(70)
t.left(120)
t.forward(50)
t.end_fill()
#vẽ mái trước
t.fillcolor("#FB7A01")
t.begin_fill()
t.penup()
t.goto(-290,-50)
t.pendown()
t.right(75)
t.forward(149)
t.left(90)
t.goto(-500,-50)
t.left(135)
t.forward(n)
t.end_fill()
#vẽ mái bên
t.fillcolor("#F74B03")
t.begin_fill()
t.left(30)
t.forward(150)
t.left(105)
t.forward(149)
t.left(75)
t.forward(150)
t.left(105)
t.goto(-290,-50)
t.end_fill()
#vẽ thân cây
t.fillcolor("#581B02")
t.begin_fill()
t.penup()
t.goto(300,-320)
t.pendown()
t.left(45)
t.forward(50)
t.left(90)
t.forward(120)
t.left(90)
t.forward(50)
t.left(90)
t.forward(120)
t.end_fill()
#vẽ tán cây thứ 1
t.fillcolor("#1EBA04")
t.begin_fill()
t.penup()
t.goto(250,-225)
t.pendown()
t.left(90)
t.forward(150)
t.left(135)
t.forward(106)
t.left(90)
t.goto(250,-225)
t.left(135)
t.end_fill()
#vẽ tán cây thứ 2
t.fillcolor("#1EBA04")
t.begin_fill()
t.penup()
t.goto(250,-150)
t.pendown()
t.forward(150)
t.left(135)
t.forward(106)
t.left(90)
t.goto(250,-150)
t.left(135)
t.end_fill()
#vẽ tán cây thứ 3
t.fillcolor("#1EBA04")
t.begin_fill()
t.penup()
t.goto(250,-75)
t.pendown()
t.forward(150)
t.left(135)
t.forward(106)
t.left(90)
t.goto(250,-75)
t.left(135)
t.end_fill()
#vẽ mat troi
#vẽ 2 tia lớn mặt trời
t.penup()
t.goto(0,150)
t.pendown()
t.forward(200)
t.penup()
t.goto(100,50)
t.pendown()
t.left(90)
t.forward(200)
#vẽ 2 tia nhỏ mặt trời
#vẽ tia nhỏ đâu
t.penup()
t.goto(100,150)
t.right(45)
t.pendown()
t.forward(80)
t.right(180)
t.forward(160)
#vẽ tai nhỏ 2
t.penup()
t.goto(100,150)
t.left(90)
t.pendown()
t.forward(80)
t.right(180)
t.forward(160)

#vẽ mặt trời màu vàng
t.fillcolor("#F8E707")
t.begin_fill()
t.penup()
t.goto(150,150)
t.pendown()
t.right(45)
t.circle(50)
t.end_fill()

turtle.done()
